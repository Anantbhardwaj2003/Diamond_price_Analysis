# %%
import pandas as pd

df = pd.read_csv('D:/diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Check for missing values
print(df.isnull().sum())

# Check for duplicates
print(df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64
# 146

# %%
# Analyze the distribution of numerical features
df.describe()
# Out:
#              carat         depth         table         price             x  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109   3933.065082      5.731214
# std        0.47339      1.429909      2.233679   3988.114460      1.120695
# min        0.20000     43.000000     43.000000    326.000000      0.000000
# 25%        0.40000     61.000000     56.000000    951.000000      4.710000
# 50%        0.70000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.04000     62.500000     59.000000   5326.750000      6.540000
# max        5.01000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53794.000000  53794.000000
# mean       5.734653      3.538714
# std        1.141209      0.705037
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.030000
# ...

# %%
# Analyze the distribution of categorical features
for col in ['cut', 'color', 'clarity']:
    print(df[col].value_counts())

# Explore relationships between features
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# cut
# Ideal        21488
# Premium      13748
# Very Good    12069
# Good          4891
# Fair          1598
# Name: count, dtype: int64
# color
# G    11262
# E     9776
# F     9520
# H     8272
# D     6755
# I     5407
# J     2802
# Name: count, dtype: int64
# clarity
# SI1     13032
# VS2     12229
# SI2      9150
# VS1      8156
# VVS2     5056
# VVS1     3647
# IF       1784
# I1        740
# Name: count, dtype: int64

# %%
# Example: Scatter plot of price vs. carat
plt.figure(figsize=(8, 6))
sns.scatterplot(x='carat', y='price', data=df)
plt.title('Price vs. Carat')
plt.show()

# %%
# Example: Box plot of price by cut
plt.figure(figsize=(8, 6))
sns.boxplot(x='cut', y='price', data=df)
plt.title('Price by Cut')
plt.show()

# %%
# Explore relationships between features using visualizations

# Price vs. Carat
plt.figure(figsize=(8, 6))
sns.scatterplot(x='carat', y='price', data=df, hue='cut') # Added hue for better visualization
plt.title('Price vs. Carat (Colored by Cut)')
plt.show()

# %%
# Pairplot to visualize relationships between multiple numerical features
sns.pairplot(df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']], diag_kind='kde')
plt.show()

# %%
# Further analysis and visualization can be done based on specific needs and questions.
# Example: Analyzing the distribution of prices for different clarity levels.
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='price', hue='clarity', multiple='stack', kde=True)
plt.title('Price Distribution by Clarity')
plt.show()

# %%
# More in-depth analysis of numerical features
numerical_features = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']
for col in numerical_features:
    print(f"Analysis of {col}:")
    print(df[col].describe())
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)  # KDE for better visualization
    plt.title(f"Distribution of {col}")
    plt.show()
# Out:
# Analysis of carat:
# count    53794.00000
# mean         0.79778
# std          0.47339
# min          0.20000
# 25%          0.40000
# 50%          0.70000
# 75%          1.04000
# max          5.01000
# Name: carat, dtype: float64
# Analysis of depth:
# count    53794.000000
# mean        61.748080
# std          1.429909
# min         43.000000
# 25%         61.000000
# 50%         61.800000
# 75%         62.500000
# max         79.000000
# Name: depth, dtype: float64
# Analysis of table:
# count    53794.000000
# mean        57.458109
# std          2.233679
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64
# Analysis of price:
# count    53794.000000
# mean      3933.065082
# std       3988.114460
# min        326.000000
# 25%        951.000000
# 50%       2401.000000
# 75%       5326.750000
# max      18823.000000
# Name: price, dtype: float64
# Analysis of x:
# ...

# %%
# Analyze the relationship between price and other numerical features
for col in numerical_features:
  if col != 'price':
    plt.figure(figsize=(8,6))
    sns.scatterplot(x=col, y='price', data=df)
    plt.title(f'Price vs. {col}')
    plt.show()

# %%
# Correlation matrix for numerical features
correlation_matrix = df[numerical_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# More detailed analysis of categorical features
for col in ['cut', 'color', 'clarity']:
    print(f"\nAnalysis of {col}:")
    print(df[col].value_counts(normalize=True)) # Show proportions
    plt.figure(figsize=(8, 6))
    sns.countplot(x=col, data=df)
    plt.title(f"Counts of {col}")
    plt.show()
# Out:
# Analysis of cut:
# cut
# Ideal        0.399450
# Premium      0.255568
# Very Good    0.224356
# Good         0.090921
# Fair         0.029706
# Name: proportion, dtype: float64
# Analysis of color:
# color
# G    0.209354
# E    0.181730
# F    0.176971
# H    0.153772
# D    0.125572
# I    0.100513
# J    0.052088
# Name: proportion, dtype: float64
# Analysis of clarity:
# clarity
# SI1     0.242258
# VS2     0.227330
# SI2     0.170093
# VS1     0.151615
# VVS2    0.093988
# VVS1    0.067796
# IF      0.033164
# I1      0.013756
# Name: proportion, dtype: float64

# %%
# Boxplot of price for each category
for col in ['cut', 'color', 'clarity']:
    print(f"\nAnalysis of {col}:")
    print(df[col].value_counts(normalize=True))    
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=col, y='price', data=df)
    plt.title(f"Price Distribution by {col}")
    plt.show()
# Out:
# Analysis of cut:
# cut
# Ideal        0.399450
# Premium      0.255568
# Very Good    0.224356
# Good         0.090921
# Fair         0.029706
# Name: proportion, dtype: float64
# Analysis of color:
# color
# G    0.209354
# E    0.181730
# F    0.176971
# H    0.153772
# D    0.125572
# I    0.100513
# J    0.052088
# Name: proportion, dtype: float64
# Analysis of clarity:
# clarity
# SI1     0.242258
# VS2     0.227330
# SI2     0.170093
# VS1     0.151615
# VVS2    0.093988
# VVS1    0.067796
# IF      0.033164
# I1      0.013756
# Name: proportion, dtype: float64

# %%
# Example: Violin plot to show distribution of price across different cuts
plt.figure(figsize=(10, 6))
sns.violinplot(x='cut', y='price', data=df)
plt.title("Price Distribution by Cut (Violin Plot)")
plt.show()
